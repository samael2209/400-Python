# %% [markdown]
# # 🐍 Funciones - Ejercicios 014 al 021
#
# En esta sección aprenderás a crear y utilizar funciones en Python. Las funciones nos permiten organizar y reutilizar código.

# %% [markdown]
# ---
#
# ## Ejercicio 014: Función con texto centrado
#
# ### Descripción
# Crear una función que escriba texto centrado en pantalla (80 columnas) con subrayado.
#
# ### Conceptos aprendidos
# - Definición de funciones con `def`
# - Parámetros de función
# - Operaciones con strings y formato

# %%
# Código del ejercicio
def EscribirCentrado(txt: str):
    a = 40 - len(txt) // 2
    print(" " * a + txt)
    print(" " * a + "=" * len(txt))

EscribirCentrado("¡Hola, Python!")

# %% [markdown]
# ---
#
# ## Ejercicio 015: Verificar múltiplos
#
# ### Descripción
# Crear una función que determine si un número es múltiplo de otro.
#
# ### Conceptos aprendidos
# - Retorno de valores con `return`
# - Tipado de parámetros y retorno
# - Operador módulo `%`

# %%
# Código del ejercicio
def EsMultiplo(n1: int, n2: int) -> bool:
    if n2 == 0:
        return False
    return n1 % n2 == 0

print(EsMultiplo(10, 5))  # True
print(EsMultiplo(7, 3))    # False

# %% [markdown]
# ---
#
# ## Ejercicio 016: Temperatura media
#
# ### Descripción
# Crear una función que calcule la temperatura media a partir de máximo y mínimo.
#
# ### Conceptos aprendidos
# - Intercambio de variables
# - Funciones con múltiples llamadas
# - Bucles `for` con `range()`

# %%
# Código del ejercicio
def TemperaturaMedia(temMax: float, temMin: float) -> float:
    if temMax < temMin:
        temMax, temMin = temMin, temMax
    return (temMax + temMin) / 2

def main():
    numDias = int(input("¿Cuántos días vas a ingresar? "))
    for i in range(numDias):
        temMax = float(input(f"Temperatura máxima del día {i+1}: "))
        temMin = float(input(f"Temperatura mínima del día {i+1}: "))
        print(f"Día {i+1}: {TemperaturaMedia(temMax, temMin):.2f}°C")

# %% [markdown]
# ---
#
# ## Ejercicio 017: Convertir espaciado
#
# ### Descripción
# Crear una función que añada un espacio después de cada carácter.
#
# ### Conceptos aprendidos
# - Iteración sobre strings
# - Método `join()` para construir cadenas
# - Comprehensions en strings

# %%
# Código del ejercicio
def ConvertirEspaciado(txt: str) -> str:
    return "".join(c + " " for c in txt)

texto = "Hola Python"
print(ConvertirEspaciado(texto))
# Resultado: 'H o l a   P y t h o n '

# %% [markdown]
# ---
#
# ## Ejercicio 018: Máximo y mínimo de lista
#
# ### Descripción
# Crear una función que devuelva el valor máximo y mínimo de una lista.
#
# ### Conceptos aprendidos
# - Iteración sobre listas
# - Retorno de tuplas
# - Asignación múltiple

# %%
# Código del ejercicio
def CalcularMaxMin(list_num: list) -> tuple:
    maximo = list_num[0]
    minimo = list_num[0]
    for num in list_num:
        if num > maximo:
            maximo = num
        if num < minimo:
            minimo = num
    return maximo, minimo

numeros = [5, 2, 8, 1, 9, 3]
maximo, minimo = CalcularMaxMin(numeros)
print(f"Máximo: {maximo}, Mínimo: {minimo}")

# %% [markdown]
# ---
#
# ## Ejercicio 019: Circunferencia (área y perímetro)
#
# ### Descripción
# Crear una función que calcule el área y perímetro de una circunferencia.
#
# ### Conceptos aprendidos
# - Importar módulos: `from math import pi`
# - Funciones conmath
# - Retorno de múltiples valores

# %%
# Código del ejercicio
from math import pi

def Circunferencia(r: float) -> tuple:
    area = pi * r ** 2
    perimetro = 2 * pi * r
    return area, perimetro

radio = 5
area, perimetro = Circunferencia(radio)
print(f"Área: {area:.2f} cm²")
print(f"Perímetro: {perimetro:.2f} cm")

# %% [markdown]
# ---
#
# ## Ejercicio 020: Sistema de Login
#
# ### Descripción
# Crear un sistema de login con 3 intentos máximos.
#
# ### Conceptos aprendidos
# - While loops
# - Contadores
# - Lógica de validación

# %%
# Código del ejercicio
def Login(usuario: str, password: str) -> bool:
    return usuario == "usuario1" and password == "asdasd"

def main():
    intentos = 3
    while intentos > 0:
        usuario = input("Usuario: ")
        password = input("Contraseña: ")
        if Login(usuario, password):
            print("¡Bienvenido!")
            return
        intentos -= 1
        print(f"Login fallido. Intentos restantes: {intentos}")
    print("Acceso denegado.")

# %% [markdown]
# ---
#
# ## Ejercicio 021: Factorial recursivo
#
# ### Descripción
# Crear una función recursiva que calcule el factorial de un número.
#
# ### Conceptos aprendidos
# - Funciones recursivas
# - Caso base en recursividad
# - Llamadas recursivas

# %%
# Código del ejercicio
def Factorial(num: int) -> int:
    if num == 0 or num == 1:
        return 1
    return num * Factorial(num - 1)

print(Factorial(5))  # 120
print(Factorial(0))  # 1

# %% [markdown]
# ---
#
# ## 📊 Resumen de Conceptos
#
# | Ejercicio | Conceptos |
# |-----------|------------|
# 014 | def, parámetros, formato de strings |
# 015 | return, tipado, operador módulo % |
# 016 | intercambio de variables, funciones con bucles |
# 017 | join(), iteración sobre strings |
# 018 | tuplas, asignación múltiple |
# 019 | math.pi, funciones matemáticas |
# 020 | while, contadores, validación |
# 021 | recursividad, caso base |

# %% [markdown]
# ---
#
# ⭐️ ¡Practica estos ejercicios para dominar las funciones en Python!
