# %% [markdown]
# # 🐍 Estructuras de Datos - Ejercicios 037 al 072
#
# En esta sección aprenderás a trabajar con listas, tuplas, diccionarios y conjuntos en Python.

# %% [markdown]
# ---
#
# ## Ejercicio 037: Listas - Operaciones completas
#
# ### Descripción
# A) Ingresar números a una lista (termina en 0)
# B) Eliminar primera ocurrencia de un número
# C) Calcular sumatoria de elementos
# D) Filtrar números menores que X
# E) Crear tuplas (número, frecuencia)

# %%
numeros = [1, 2, 3, 2, 4, 2]
numeros.remove(2)
print(numeros)
print(sum(numeros))
print([n for n in numeros if n < 3])

# %% [markdown]
# ---
#
# ## Ejercicio 038: Pasajeros y Ciudades
#
# ### Descripción
# Gestionar pasajeros con tuplas (nombre, DNI, destino) y ciudades con (ciudad, país).

# %%
pasajeros = [("Manuel", 12345, "Buenos Aires")]
def buscar(dni):
    for nombre, d, destino in pasajeros:
        if d == dni: return destino
    return "No encontrado"
print(buscar(12345))

# %% [markdown]
# ---
#
# ## Ejercicio 039: Conjuntos
#
# ### Descripción
# Comparar listas de alumnos usando conjuntos.

# %%
primaria = {"Ana", "Juan"}
secundaria = {"Juan", "Maria"}
print("Repetidos:", primaria & secundaria)
print("Solo primaria:", primaria - secundaria)

# %% [markdown]
# ---
#
# ## Ejercicio 040: Diccionarios para Facturación
#
# ### Descripción
# Obtener domicilios únicos de clientes.

# %%
ventas = [("Ana", 100, "Calle 1"), ("Ana", 200, "Calle 1")]
facturas = {}
for cliente, monto, dom in ventas:
    facturas[cliente] = facturas.get(cliente, 0) + monto
print(facturas)

# %% [markdown]
# ---
#
# ## Ejercicio 041: Contador de caracteres
#
# ### Descripción
# Contar ocurrencias de cada carácter.

# %%
texto = "hola"
contador = {}
for c in texto:
    contador[c] = contador.get(c, 0) + 1
print(contador)

# %% [markdown]
# ---
#
# ## Ejercicio 042: Club de Socios
#
# ### Descripción
# Gestionar socios con diccionario.

# %%
socios = {1: ["Ana", "17/03/2009", "s"]}
socios[2] = ["Juan", "20/05/2020", "n"]
print(socios)

# %% [markdown]
# ---
#
# ## Ejercicio 043: Contar Elementos
#
# ### Descripción
# Contar元素的频率.

# %%
elementos = [1, 1, 2, 3, 2, 1]
contador = {}
for e in elementos:
    contador[e] = contador.get(e, 0) + 1
print(contador)

# %% [markdown]
# ---
#
# ## Ejercicio 044: Calcular Promedio
#
# ### Descripción
# Calcular promedio de calificaciones.

# %%
notas = {'Ana': 8, 'Juan': 6}
print(sum(notas.values()) / len(notas))

# %% [markdown]
# ---
#
# ## Ejercicio 045: Filtrar por Valor
#
# ### Descripción
# Filtrar diccionario por valor.

# %%
est = {'Ana': 'aprovado', 'Juan': 'reprovado'}
print({k:v for k,v in est.items() if v == 'aprovado'})

# %% [markdown]
# ---
#
# ## Ejercicio 046: Unir Diccionarios
#
# ### Descripción
# Combinar dos diccionarios.

# %%
d1 = {'a': 1}
d2 = {'b': 2}
d1.update(d2)
print(d1)

# %% [markdown]
# ---
#
# ## Ejercicio 047: Contar Palabras
#
# ### Descripción
# Contar palabras en un texto.

# %%
texto = "hola hola mundo"
contador = {}
for palabra in texto.split():
    contador[palabra] = contador.get(palabra, 0) + 1
print(contador)

# %% [markdown]
# ---
#
# ## Ejercicio 048: Eliminar Duplicados
#
# ### Descripción
# Eliminar elementos duplicados.

# %%
lista = [1, 1, 2, 3, 3]
print(list(set(lista)))

# %% [markdown]
# ---
#
# ## Ejercicio 049: Valor Mínimo y Máximo
#
# ### Descripción
# Encontrar min y max en diccionario.

# %%
d = {'a': 10, 'b': 5, 'c': 20}
valores = list(d.values())
print(f"Min: {min(valores)}, Max: {max(valores)}")

# %% [markdown]
# ---
#
# ## Ejercicio 050: Eliminar Claves por Umbral
#
# ### Descripción
# Eliminar claves cuyo valor > umbral.

# %%
d = {'a': 5, 'b': 20, 'c': 15}
print({k:v for k,v in d.items() if v <= 10})

# %% [markdown]
# ---
#
# ## Ejercicio 051: Invertir Diccionario
#
# ### Descripción
# Invertir claves y valores.

# %%
d = {'a': 1, 'b': 2}
print({v:k for k,v in d.items()})

# %% [markdown]
# ---
#
# ## Ejercicio 052: Histograma
#
# ### Descripción
# Crear histograma de letras.

# %%
txt = "hello"
h = {}
for c in txt:
    h[c] = h.get(c, 0) + 1
print(h)

# %% [markdown]
# ---
#
# ## Ejercicio 053: Diccionario Anidado CRUD
#
# ### Descripción
# CRUD completo con diccionario anidado.

# %%
tienda = {'manzana': {'precio': 1.5, 'stock': 10}}
tienda['banana'] = {'precio': 0.8, 'stock': 20}
print(tienda)

# %% [markdown]
# ---
#
# ## Ejercicio 054: Contar Vocales
#
# ### Descripción
# Contar vocales en un texto.

# %%
vocales = "aeiou"
texto = "Hola Mundo"
print({v: texto.lower().count(v) for v in vocales})

# %% [markdown]
# ---
#
# ## Ejercicio 055: Ordenar Diccionario
#
# ### Descripción
# Ordenar diccionario por claves o valores.

# %%
d = {'z': 3, 'a': 1, 'b': 2}
print(sorted(d.keys()))
print(sorted(d.items(), key=lambda x: x[1]))

# %% [markdown]
# ---
#
# ## Ejercicio 056: Diccionario Vacío
#
# ### Descripción
# Verificar si un diccionario está vacío.

# %%
d = {}
print(not d)

# %% [markdown]
# ---
#
# ## Ejercicio 057: Buscar Clave
#
# ### Descripción
# Buscar una clave y devolver su valor.

# %%
d = {'a': 1, 'b': 2}
print(d.get('a', 'No encontrado'))

# %% [markdown]
# ---
#
# ## Ejercicio 058: Eliminar Clave
#
# ### Descripción
# Eliminar una clave de un diccionario.

# %%
d = {'a': 1, 'b': 2}
del d['a']
print(d)

# %% [markdown]
# ---
#
# ## Ejercicio 059: Diccionario de Contactos
#
# ### Descripción
# CRUD de contactos con diccionario.

# %%
contactos = {}
contactos['Ana'] = '1234-5678'
print(contactos)

# %% [markdown]
# ---
#
# ## Ejercicio 060: Unir Listas en Diccionario
#
# ### Descripción
# Convertir dos listas en diccionario.

# %%
claves = ['a', 'b', 'c']
valores = [1, 2, 3]
print(dict(zip(claves, valores)))

# %% [markdown]
# ---
#
# ## Ejercicio 061: Diccionario de Frecuencias
#
# ### Descripción
# Contar frecuencia de números.

# %%
nums = [1, 2, 2, 3, 3, 3]
freq = {}
for n in nums: freq[n] = freq.get(n, 0) + 1
print(freq)

# %% [markdown]
# ---
#
# ## Ejercicio 062: Diccionario de Traducción
#
# ### Descripción
# Traductor simple inglés-español.

# %%
trad = {'hello': 'hola', 'bye': 'adios'}
print(trad['hello'])

# %% [markdown]
# ---
#
# ## Ejercicio 063: Registro de Ventas
#
# ### Descripción
# Registro de ventas diarias con fechas como claves.
#
# ### Conceptos aprendidos
# - `datetime` module
# - Listas de diccionarios

# %%
from datetime import datetime
ventas = {datetime(2024, 1, 1): []}
ventas[datetime(2024, 1, 1)].append({'producto': 'Manzana', 'cantidad': 3, 'precio': 1.5})
print(ventas)

# %% [markdown]
# ---
#
# ## Ejercicio 064: Puntuaciones de Jugadores
#
# ### Descripción
# Diccionario con tuplas de puntuaciones.
#
# ### Conceptos aprendidos
# - Tuplas
# - Agregar a tupla

# %%
puntuaciones = {'Juan': (10, 20)}
puntuaciones['Juan'] += (30,)
print(puntuaciones)

# %% [markdown]
# ---
#
# ## Ejercicio 065: Diccionario de Estudiantes
#
# ### Descripción
# Estudiantes con cursos y calificaciones.
#
# ### Conceptos aprendidos
# - Diccionarios anidados
# - CRUD

# %%
estudiantes = {}
estudiantes['Ana'] = {'cursos': ['Matemáticas'], 'calificaciones': (8,)}
print(estudiantes)

# %% [markdown]
# ---
#
# ## Ejercicio 066: Inventario de Tienda
#
# ### Descripción
# Gestionar productos con detalles.
#
# ### Conceptos aprendidos
# - Diccionarios con múltiples campos
# - Actualización

# %%
tienda = {'Manzana': {'precio': 1.5, 'stock': 10}}
tienda['Manzana']['stock'] = 9
print(tienda)

# %% [markdown]
# ---
#
# ## Ejercicio 067: Registro de Películas
#
# ### Descripción
# Películas con actores como tuplas.
#
# ### Conceptos aprendidos
# - Listas de tuplas
# - CRUD básico

# %%
peliculas = {}
peliculas['Inception'] = {'año': 2010, 'actores': [('DiCaprio', 'Protagonista')]}
print(peliculas)

# %% [markdown]
# ---
#
# ## Ejercicio 068: Almacenamiento de Recetas
#
# ### Descripción
# Recetas con ingredientes y cantidades.
#
# ### Conceptos aprendidos
# - Listas de tuplas
# - Estructura anidada

# %%
recetas = {}
recetas['Tarta'] = {'ingredientes': [('Harina', '200g')]}
print(recetas)

# %% [markdown]
# ---
#
# ## Ejercicio 069: Directorio Telefónico
#
# ### Descripción
# Contactos con teléfono y email.
#
# ### Conceptos aprendidos
# - Tuplas como valores
# - CRUD

# %%
contactos = {}
contactos['Ana'] = [('1234', 'ana@gmail.com')]
print(contactos)

# %% [markdown]
# ---
#
# ## Ejercicio 070: Registro de Compras
#
# ### Descripción
# Compras con UUID único.
#
# ### Conceptos aprendidos
# - `uuid` module
# - Listas de tuplas

# %%
import uuid
compras = {}
compras[uuid.uuid4()] = [('Manzana', 3)]
print(compras)

# %% [markdown]
# ---
#
# ## Ejercicio 071: Registro de Viajes
#
# ### Descripción
# Viajes con lugares visitados y descripción.
#
# ### Conceptos aprendidos
# - Listas de tuplas
# - CRUD completo

# %%
viajes = {}
viajes['París'] = {'lugares': [('Torre Eiffel', '2024-01-15')], 'descripcion': 'Romántico'}
print(viajes)

# %% [markdown]
# ---
#
# ## Ejercicio 072: Sistema de Pedidos
#
# ### Descripción
# Pedidos con elementos y estados.
#
# ### Conceptos aprendidos
# - UUID único
# - Control de estados

# %%
import uuid
pedidos = {}
pedidos[uuid.uuid4()] = {'elementos': [('Pizza', 2)], 'estado': 'pendiente'}
print(pedidos)

# %% [markdown]
# ---
#
# ⭐️ ¡Sección 03_estructuras_datos completada! (037-072)
